# %%
# sample and concatinate 10s snipits from 300 games and save using ffmpeg
import os


fp = '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays'
video_fps = []

for root, dirs, files in os.walk(fp):
    for file in files:
        if file.endswith('mp4') or file.endswith('avi'):
            full_path = os.path.join(root, file)
            video_fps.append(full_path)

# %%
import os
import random
import subprocess

def extract_random_clip(video_path, num_frames, output_path):
    # Get the frame rate of the video
    probe_cmd = ['ffprobe', '-v', 'error', '-select_streams', 'v:0', '-show_entries', 
                 'stream=r_frame_rate', '-of', 'default=noprint_wrappers=1:nokey=1', video_path]
    result = subprocess.run(probe_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    
    if result.returncode != 0:
        raise Exception(f"ffprobe error: {result.stderr.strip()}")

    # Calculate the duration in seconds for the given number of frames
    frame_rate = eval(result.stdout.strip())  # Frame rate as a fraction, e.g., '30/1'
    duration_seconds = num_frames / frame_rate  # Duration for num_frames frames
    
    # Get the total duration of the video in seconds
    probe_duration_cmd = ['ffprobe', '-v', 'error', '-show_entries', 'format=duration',
                          '-of', 'default=noprint_wrappers=1:nokey=1', video_path]
    total_duration_result = subprocess.run(probe_duration_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    total_duration = float(total_duration_result.stdout.strip())

    assert total_duration > duration_seconds, "Video is too short for clipping."

    # Generate a random start time
    max_start_time = total_duration - duration_seconds
    start_time = random.uniform(0, max_start_time)

    # Build the ffmpeg command for extracting the clip
    ffmpeg_cmd = [
        'ffmpeg', '-y', '-ss', str(start_time), '-t', str(duration_seconds), 
        '-i', video_path, '-c:v', 'libx264', '-c:a', 'aac', '-strict', 'experimental', 
        output_path
    ]
    subprocess.run(ffmpeg_cmd, check=True)

def concatenate_clips(clip_paths, output_path):
    """
    Concatenates multiple video clips into a single video file.

    Args:
    clip_paths (list of str): A list of paths to the video clips.
    output_path (str): The path where the concatenated video will be saved.

    Returns:
    None
    """
    # Create a temporary file to list all clip paths
    with open('filelist.txt', 'w') as file:
        for path in clip_paths:
            file.write(f"file '{path}'\n")

    # Build the ffmpeg command for concatenation
    ffmpeg_cmd = [
        'ffmpeg', '-y', '-f', 'concat', '-safe', '0', '-i', 'filelist.txt', 
        '-c', 'copy', output_path
    ]
    subprocess.run(ffmpeg_cmd, check=True)
    os.remove('filelist.txt')  # Clean up temporary file

def process_videos(video_paths, num_clips, clip_duration, output_video):
    """
    Processes a list of video paths to create a single video composed of random clips.

    Args:
    video_paths (list of str): The list of video paths.
    num_clips (int): Number of random clips to extract.
    clip_duration (int): Duration of each clip in seconds.
    output_video (str): The output video path.

    Returns:
    None
    """
    assert len(video_paths) >= num_clips, "Not enough video paths provided."

    selected_paths = random.sample(video_paths, num_clips)
    clip_files = []

    for i, path in enumerate(selected_paths):
        try:
            output_path = f"temp_clip_{i}.mp4"
            extract_random_clip(path, clip_duration, output_path)
            clip_files.append(output_path)
        except:
            print(f"Error: could not process clip @ {path}")

    concatenate_clips(clip_files, output_video)

    # Cleanup temporary clips
    for clip in clip_files:
        os.remove(clip)

process_videos(video_fps, 300, 10, 'multi-league-30x10.mp4')
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/1012034_132871_BC Frankivsk Prykarpattya_133042_DSK Levhartice Chomutov_period4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 375
#     encoder         : Lavf58.29.100
#   Duration: 00:22:57.46, start: 0.000000, bitrate: 754 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 651 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12a01ee00] using SAR=1/1
# [libx264 @ 0x12a01ee00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12a01ee00] profile High, level 3.0
# [libx264 @ 0x12a01ee00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 375
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   11 fps=0.0 q=-1.0 Lsize=      49kB time=00:00:00.37 bitrate=1073.0kbits/s dup=1 drop=0 speed=7.36x
# video:42kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.710872%
# [libx264 @ 0x12a01ee00] frame I:1     Avg QP:23.41  size: 26383
# [libx264 @ 0x12a01ee00] frame P:3     Avg QP:26.54  size:  3879
# [libx264 @ 0x12a01ee00] frame B:7     Avg QP:28.87  size:   602
# [libx264 @ 0x12a01ee00] consecutive B-frames:  9.1% 18.2%  0.0% 72.7%
# [libx264 @ 0x12a01ee00] mb I  I16..4:  6.2% 38.2% 55.6%
# [libx264 @ 0x12a01ee00] mb P  I16..4:  0.3%  0.4%  0.3%  P16..4: 33.1% 11.3%  7.6%  0.0%  0.0%    skip:47.1%
# [libx264 @ 0x12a01ee00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 28.9%  1.8%  0.6%  direct: 0.4%  skip:68.2%  L0:42.1% L1:54.0% BI: 4.0%
# [libx264 @ 0x12a01ee00] 8x8 transform intra:38.2% inter:46.7%
# [libx264 @ 0x12a01ee00] coded y,uvDC,uvAC intra: 84.0% 92.2% 52.9% inter: 5.7% 6.2% 0.2%
# [libx264 @ 0x12a01ee00] i16 v,h,dc,p:  5% 51%  4% 40%
# [libx264 @ 0x12a01ee00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 43% 15%  5%  3%  4%  6%  3% 10%
# [libx264 @ 0x12a01ee00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 36% 11%  4%  5%  5%  7%  4%  6%
# [libx264 @ 0x12a01ee00] i8c dc,h,v,p: 38% 37% 16%  8%
# [libx264 @ 0x12a01ee00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12a01ee00] ref P L0: 79.3% 10.2%  7.6%  2.9%
# [libx264 @ 0x12a01ee00] ref B L0: 91.3%  8.5%  0.2%
# [libx264 @ 0x12a01ee00] ref B L1: 98.8%  1.2%
# [libx264 @ 0x12a01ee00] kb/s:921.43
# [aac @ 0x12a00fa00] Qavg: 7448.638
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/972674_75076_Manchester_1319_Franklin_period1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#   Duration: 00:17:36.60, start: 0.000000, bitrate: 619 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 517 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x15c009200] using SAR=1/1
# [libx264 @ 0x15c009200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15c009200] profile High, level 3.0
# [libx264 @ 0x15c009200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   11 fps=0.0 q=-1.0 Lsize=      49kB time=00:00:00.37 bitrate=1088.7kbits/s dup=1 drop=0 speed=10.5x
# video:42kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.657762%
# [libx264 @ 0x15c009200] frame I:1     Avg QP:23.23  size: 36698
# [libx264 @ 0x15c009200] frame P:3     Avg QP:26.21  size:  1392
# [libx264 @ 0x15c009200] frame B:7     Avg QP:29.86  size:   272
# [libx264 @ 0x15c009200] consecutive B-frames:  9.1% 18.2%  0.0% 72.7%
# [libx264 @ 0x15c009200] mb I  I16..4:  9.4% 16.7% 73.9%
# [libx264 @ 0x15c009200] mb P  I16..4:  0.5%  0.7%  0.1%  P16..4: 14.2%  4.4%  3.3%  0.0%  0.0%    skip:76.8%
# [libx264 @ 0x15c009200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 11.8%  0.8%  0.2%  direct: 0.2%  skip:87.0%  L0:44.5% L1:54.0% BI: 1.5%
# [libx264 @ 0x15c009200] 8x8 transform intra:18.2% inter:54.6%
# [libx264 @ 0x15c009200] coded y,uvDC,uvAC intra: 77.4% 75.3% 47.4% inter: 2.5% 3.7% 0.1%
# [libx264 @ 0x15c009200] i16 v,h,dc,p: 40% 16% 18% 27%
# [libx264 @ 0x15c009200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 24% 23%  3%  3%  4%  6%  3%  7%
# [libx264 @ 0x15c009200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 34% 11%  4%  5%  4%  8%  4%  9%
# [libx264 @ 0x15c009200] i8c dc,h,v,p: 47% 32% 14%  8%
# [libx264 @ 0x15c009200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x15c009200] ref P L0: 83.7%  7.7%  4.8%  3.8%
# [libx264 @ 0x15c009200] ref B L0: 92.3%  6.6%  1.1%
# [libx264 @ 0x15c009200] ref B L1: 98.7%  1.3%
# [libx264 @ 0x15c009200] kb/s:933.34
# [aac @ 0x15c00aa00] Qavg: 7404.588
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/990335_1265_UCLA_1708_Washington State_period2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#   Duration: 00:52:16.83, start: 0.000000, bitrate: 835 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 732 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12581e400] using SAR=1/1
# [libx264 @ 0x12581e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12581e400] profile High, level 3.0
# [libx264 @ 0x12581e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   10 fps=0.0 q=-1.0 Lsize=      66kB time=00:00:00.37 bitrate=1459.0kbits/s speed=8.59x
# video:59kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.666788%
# [libx264 @ 0x12581e400] frame I:1     Avg QP:25.33  size: 45557
# [libx264 @ 0x12581e400] frame P:3     Avg QP:29.40  size:  3368
# [libx264 @ 0x12581e400] frame B:6     Avg QP:30.78  size:   713
# [libx264 @ 0x12581e400] consecutive B-frames: 20.0%  0.0%  0.0% 80.0%
# [libx264 @ 0x12581e400] mb I  I16..4:  2.9% 12.1% 85.0%
# [libx264 @ 0x12581e400] mb P  I16..4:  0.0%  0.0%  0.4%  P16..4: 23.5% 13.1%  8.4%  0.0%  0.0%    skip:54.5%
# [libx264 @ 0x12581e400] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 28.8%  3.1%  0.8%  direct: 0.9%  skip:66.3%  L0:48.1% L1:43.4% BI: 8.5%
# [libx264 @ 0x12581e400] 8x8 transform intra:12.0% inter:24.9%
# [libx264 @ 0x12581e400] coded y,uvDC,uvAC intra: 88.3% 89.1% 73.4% inter: 5.2% 3.2% 0.3%
# [libx264 @ 0x12581e400] i16 v,h,dc,p:  3% 78%  9%  9%
# [libx264 @ 0x12581e400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 33% 21%  2%  2%  4%  6%  2%  8%
# [libx264 @ 0x12581e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 25% 10%  5%  8%  8%  8%  6%  9%
# [libx264 @ 0x12581e400] i8c dc,h,v,p: 42% 33% 18%  7%
# [libx264 @ 0x12581e400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12581e400] ref P L0: 82.5%  9.1%  6.9%  1.5%
# [libx264 @ 0x12581e400] ref B L0: 95.2%  2.9%  1.9%
# [libx264 @ 0x12581e400] ref B L1: 99.2%  0.8%
# [libx264 @ 0x12581e400] kb/s:1438.49
# [aac @ 0x12581fc00] Qavg: 7421.089
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/991580_2765_Bloomfield_944_Felician_period2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#   Duration: 00:33:24.95, start: 0.000000, bitrate: 629 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 526 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x11f81e400] using SAR=1/1
# [libx264 @ 0x11f81e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x11f81e400] profile High, level 3.0
# [libx264 @ 0x11f81e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   11 fps=0.0 q=-1.0 Lsize=      55kB time=00:00:00.37 bitrate=1211.1kbits/s dup=1 drop=0 speed=10.7x
# video:48kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.245406%
# [libx264 @ 0x11f81e400] frame I:1     Avg QP:24.92  size: 21780
# [libx264 @ 0x11f81e400] frame P:3     Avg QP:27.10  size:  5162
# [libx264 @ 0x11f81e400] frame B:7     Avg QP:29.04  size:  1637
# [libx264 @ 0x11f81e400] consecutive B-frames:  9.1%  0.0% 54.5% 36.4%
# [libx264 @ 0x11f81e400] mb I  I16..4: 14.6% 45.2% 40.2%
# [libx264 @ 0x11f81e400] mb P  I16..4:  3.9%  4.0%  2.8%  P16..4: 40.2% 18.8%  8.0%  0.0%  0.0%    skip:22.2%
# [libx264 @ 0x11f81e400] mb B  I16..4:  0.1%  0.0%  0.1%  B16..8: 42.6%  8.2%  1.4%  direct: 0.8%  skip:46.9%  L0:52.3% L1:43.5% BI: 4.2%
# [libx264 @ 0x11f81e400] 8x8 transform intra:43.1% inter:66.7%
# [libx264 @ 0x11f81e400] coded y,uvDC,uvAC intra: 65.6% 74.8% 34.8% inter: 9.4% 9.0% 0.4%
# [libx264 @ 0x11f81e400] i16 v,h,dc,p:  7% 58%  3% 32%
# [libx264 @ 0x11f81e400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 37% 14%  5%  4%  4%  7%  6%  9%
# [libx264 @ 0x11f81e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 40% 12%  4%  4%  5%  6%  3%  6%
# [libx264 @ 0x11f81e400] i8c dc,h,v,p: 40% 39% 15%  6%
# [libx264 @ 0x11f81e400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x11f81e400] ref P L0: 77.0% 14.0%  6.0%  3.0%
# [libx264 @ 0x11f81e400] ref B L0: 86.4% 12.4%  1.2%
# [libx264 @ 0x11f81e400] kb/s:1063.13
# [aac @ 0x11f809800] Qavg: 7444.011
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/975439_12345_Akron_12378_Eastern Michigan_period3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 672
#     encoder         : Lavf58.29.100
#   Duration: 00:26:10.37, start: 0.000000, bitrate: 610 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 608 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x140809200] using SAR=1/1
# [libx264 @ 0x140809200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x140809200] profile High, level 3.0
# [libx264 @ 0x140809200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 672
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   10 fps=0.0 q=-1.0 Lsize=      48kB time=00:00:00.26 bitrate=1470.5kbits/s speed=4.51x
# video:47kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.214068%
# [libx264 @ 0x140809200] frame I:1     Avg QP:26.25  size: 12331
# [libx264 @ 0x140809200] frame P:4     Avg QP:26.22  size:  6330
# [libx264 @ 0x140809200] frame B:5     Avg QP:28.23  size:  1927
# [libx264 @ 0x140809200] consecutive B-frames: 20.0% 40.0%  0.0% 40.0%
# [libx264 @ 0x140809200] mb I  I16..4:  9.5% 65.5% 25.1%
# [libx264 @ 0x140809200] mb P  I16..4:  4.8% 11.0%  8.1%  P16..4: 40.7% 18.0%  5.6%  0.0%  0.0%    skip:11.8%
# [libx264 @ 0x140809200] mb B  I16..4:  0.3%  0.3%  0.2%  B16..8: 47.1% 10.8%  1.0%  direct: 0.9%  skip:39.3%  L0:40.7% L1:55.4% BI: 3.8%
# [libx264 @ 0x140809200] 8x8 transform intra:55.4% inter:66.7%
# [libx264 @ 0x140809200] coded y,uvDC,uvAC intra: 56.5% 60.5% 13.6% inter: 12.9% 13.6% 0.2%
# [libx264 @ 0x140809200] i16 v,h,dc,p: 33% 33% 10% 24%
# [libx264 @ 0x140809200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 24% 17%  4%  4%  6%  6%  7%  7%
# [libx264 @ 0x140809200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 20% 15%  4%  6%  7%  7%  6%  3%
# [libx264 @ 0x140809200] i8c dc,h,v,p: 50% 20% 22%  8%
# [libx264 @ 0x140809200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x140809200] ref P L0: 77.7% 12.0%  8.9%  1.4%
# [libx264 @ 0x140809200] ref B L0: 97.8%  1.5%  0.7%
# [libx264 @ 0x140809200] ref B L1: 99.3%  0.7%
# [libx264 @ 0x140809200] kb/s:1134.96
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/988750_1142_Jacksonville State_679_Lipscomb_period1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#   Duration: 00:42:30.77, start: 0.000000, bitrate: 747 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 645 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14d01e400] using SAR=1/1
# [libx264 @ 0x14d01e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14d01e400] profile High, level 3.0
# [libx264 @ 0x14d01e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   10 fps=0.0 q=-1.0 Lsize=      33kB time=00:00:00.37 bitrate= 730.7kbits/s speed=8.93x
# video:26kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.470426%
# [libx264 @ 0x14d01e400] frame I:1     Avg QP:23.82  size: 10302
# [libx264 @ 0x14d01e400] frame P:3     Avg QP:26.63  size:  4141
# [libx264 @ 0x14d01e400] frame B:6     Avg QP:28.21  size:   531
# [libx264 @ 0x14d01e400] consecutive B-frames: 20.0%  0.0%  0.0% 80.0%
# [libx264 @ 0x14d01e400] mb I  I16..4: 22.3% 59.9% 17.8%
# [libx264 @ 0x14d01e400] mb P  I16..4:  8.7% 19.9%  5.4%  P16..4: 30.4%  4.9%  2.0%  0.0%  0.0%    skip:28.6%
# [libx264 @ 0x14d01e400] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 26.3%  1.7%  0.1%  direct: 0.2%  skip:71.4%  L0:50.3% L1:46.9% BI: 2.8%
# [libx264 @ 0x14d01e400] 8x8 transform intra:59.1% inter:74.5%
# [libx264 @ 0x14d01e400] coded y,uvDC,uvAC intra: 39.5% 33.3% 13.1% inter: 4.5% 4.0% 0.0%
# [libx264 @ 0x14d01e400] i16 v,h,dc,p: 20% 47% 19% 15%
# [libx264 @ 0x14d01e400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 25% 23%  3%  3%  3%  3%  4%  4%
# [libx264 @ 0x14d01e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 28% 10%  6%  6%  6%  6%  6%  4%
# [libx264 @ 0x14d01e400] i8c dc,h,v,p: 64% 20% 12%  4%
# [libx264 @ 0x14d01e400] Weighted P-Frames: Y:66.7% UV:66.7%
# [libx264 @ 0x14d01e400] ref P L0: 24.8%  2.1%  4.4% 42.9% 25.8%
# [libx264 @ 0x14d01e400] ref B L0: 96.7%  3.2%  0.1%
# [libx264 @ 0x14d01e400] ref B L1: 99.3%  0.7%
# [libx264 @ 0x14d01e400] kb/s:621.86
# [aac @ 0x14d009200] Qavg: 7424.528
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/972497_21615_Colorado_421_UCLA_period2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#   Duration: 00:22:31.26, start: 0.000000, bitrate: 864 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 762 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12981aa00] using SAR=1/1
# [libx264 @ 0x12981aa00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12981aa00] profile High, level 3.0
# [libx264 @ 0x12981aa00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 6617
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   10 fps=0.0 q=-1.0 Lsize=      72kB time=00:00:00.37 bitrate=1590.5kbits/s speed=8.55x
# video:65kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.440953%
# [libx264 @ 0x12981aa00] frame I:1     Avg QP:26.00  size: 31069
# [libx264 @ 0x12981aa00] frame P:3     Avg QP:29.28  size:  6530
# [libx264 @ 0x12981aa00] frame B:6     Avg QP:30.35  size:  2552
# [libx264 @ 0x12981aa00] consecutive B-frames: 20.0%  0.0%  0.0% 80.0%
# [libx264 @ 0x12981aa00] mb I  I16..4:  2.5% 50.6% 46.8%
# [libx264 @ 0x12981aa00] mb P  I16..4:  0.5%  1.9%  1.6%  P16..4: 35.2% 17.9% 12.0%  0.0%  0.0%    skip:30.8%
# [libx264 @ 0x12981aa00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 42.0% 10.6%  3.1%  direct: 2.7%  skip:41.5%  L0:31.2% L1:58.5% BI:10.4%
# [libx264 @ 0x12981aa00] 8x8 transform intra:50.2% inter:58.7%
# [libx264 @ 0x12981aa00] coded y,uvDC,uvAC intra: 83.9% 77.5% 38.5% inter: 16.5% 12.7% 0.3%
# [libx264 @ 0x12981aa00] i16 v,h,dc,p:  7% 76%  4% 13%
# [libx264 @ 0x12981aa00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 42% 11%  5%  5%  5%  7%  5%  8%
# [libx264 @ 0x12981aa00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 40%  9%  5%  6%  6%  7%  5%  7%
# [libx264 @ 0x12981aa00] i8c dc,h,v,p: 38% 39% 14%  8%
# [libx264 @ 0x12981aa00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12981aa00] ref P L0: 74.8% 12.9%  9.9%  2.4%
# [libx264 @ 0x12981aa00] ref B L0: 97.9%  1.7%  0.4%
# [libx264 @ 0x12981aa00] ref B L1: 98.3%  1.7%
# [libx264 @ 0x12981aa00] kb/s:1583.38
# [aac @ 0x12980a400] Qavg: 7430.415
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/975529_21849_Chico State_1538_San Francisco State_period2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#   Duration: 00:17:24.02, start: 0.000000, bitrate: 753 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 651 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13a00e800] using SAR=1/1
# [libx264 @ 0x13a00e800] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13a00e800] profile High, level 3.0
# [libx264 @ 0x13a00e800] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 5536
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   11 fps=0.0 q=-1.0 Lsize=      51kB time=00:00:00.37 bitrate=1133.0kbits/s dup=1 drop=0 speed=10.7x
# video:44kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.509462%
# [libx264 @ 0x13a00e800] frame I:1     Avg QP:25.50  size: 17446
# [libx264 @ 0x13a00e800] frame P:3     Avg QP:27.51  size:  6026
# [libx264 @ 0x13a00e800] frame B:7     Avg QP:29.73  size:  1294
# [libx264 @ 0x13a00e800] consecutive B-frames:  9.1% 18.2%  0.0% 72.7%
# [libx264 @ 0x13a00e800] mb I  I16..4:  8.1% 59.5% 32.4%
# [libx264 @ 0x13a00e800] mb P  I16..4:  3.0%  5.5%  5.4%  P16..4: 41.6% 14.7%  6.0%  0.0%  0.0%    skip:23.8%
# [libx264 @ 0x13a00e800] mb B  I16..4:  0.0%  0.1%  0.1%  B16..8: 34.6%  5.9%  1.2%  direct: 0.7%  skip:57.4%  L0:57.6% L1:36.4% BI: 6.0%
# [libx264 @ 0x13a00e800] 8x8 transform intra:53.5% inter:61.2%
# [libx264 @ 0x13a00e800] coded y,uvDC,uvAC intra: 70.1% 75.9% 29.6% inter: 9.4% 10.8% 0.4%
# [libx264 @ 0x13a00e800] i16 v,h,dc,p:  4% 72%  4% 21%
# [libx264 @ 0x13a00e800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 53% 11%  4%  3%  3%  6%  4%  6%
# [libx264 @ 0x13a00e800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 42% 11%  5%  5%  4%  6%  5%  5%
# [libx264 @ 0x13a00e800] i8c dc,h,v,p: 41% 37% 16%  6%
# [libx264 @ 0x13a00e800] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13a00e800] ref P L0: 87.0%  7.3%  4.1%  1.5%
# [libx264 @ 0x13a00e800] ref B L0: 96.2%  3.8%
# [libx264 @ 0x13a00e800] ref B L1: 99.8%  0.2%
# [libx264 @ 0x13a00e800] kb/s:972.74
# [aac @ 0x13a010000] Qavg: 7445.326
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/940722_3636_Brisbane Bullets_89_New Zealand Breakers_period1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 3676
#     encoder         : Lavf58.29.100
#   Duration: 00:18:50.63, start: 0.000000, bitrate: 1048 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], 946 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x154009200] using SAR=1/1
# [libx264 @ 0x154009200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x154009200] profile High, level 3.0
# [libx264 @ 0x154009200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'temp_clip_8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : InStat Football videolibrary
#     artist          : vcoder 3676
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 704x400 [SAR 1:1 DAR 44:25], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 aac
# frame=   10 fps=0.0 q=-1.0 Lsize=      68kB time=00:00:00.37 bitrate=1497.8kbits/s speed=8.19x
# video:61kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.571778%
# [libx264 @ 0x154009200] frame I:1     Avg QP:26.96  size: 25243
# [libx264 @ 0x154009200] frame P:4     Avg QP:28.65  size:  8714
# [libx264 @ 0x154009200] frame B:5     Avg QP:30.54  size:   294
# [libx264 @ 0x154009200] consecutive B-frames: 20.0% 20.0% 60.0%  0.0%
# [libx264 @ 0x154009200] mb I  I16..4:  1.9% 53.0% 45.1%
# [libx264 @ 0x154009200] mb P  I16..4:  1.2%  8.0%  7.1%  P16..4: 41.4% 22.2%  8.6%  0.0%  0.0%    skip:11.5%
# [libx264 @ 0x154009200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.5%  0.3%  0.0%  direct: 0.0%  skip:84.2%  L0:36.2% L1:63.8% BI: 0.0%
# [libx264 @ 0x154009200] 8x8 transform intra:51.5% inter:50.2%
# [libx264 @ 0x154009200] coded y,uvDC,uvAC intra: 84.2% 88.2% 51.2% inter: 13.8% 15.6% 2.6%
# [libx264 @ 0x154009200] i16 v,h,dc,p:  5% 43%  7% 45%
# [libx264 @ 0x154009200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 28% 12%  6%  7%  6%  9%  6% 12%
# [libx264 @ 0x154009200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 28% 12%  6%  7%  8%  8%  6%  8%
# [libx264 @ 0x154009200] i8c dc,h,v,p: 43% 28% 18% 11%
# [libx264 @ 0x154009200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x154009200] ref P L0: 71.3% 20.4%  5.4%  2.8%
# [libx264 @ 0x154009200] ref B L0: 99.4%  0.6%
# [libx264 @ 0x154009200] kb/s:1477.58
# [aac @ 0x15400aa00] Qavg: 7423.483
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Volumes/BBall_Data_23X_pt2/HUDL_basketball_data_pt2/22-23/misc-replays/987955_715_North Dakota State_809_UMKC_period2.mp4':
#   Metadata:
# ...
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680d600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015c00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 5 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 7 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015c00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 4 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126814200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12780ea00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127017a00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116810e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015c00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12681c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 7 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126816600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11680ea00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680ca00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116810e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126814200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12681ce00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015c00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126814200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127017600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12701ae00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter 153x
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127016200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127015600] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12681e200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12681c200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127011200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12680c200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126809200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 9 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11680fa00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 9 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116812800] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116810200] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x116808200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 7 times
# frame= 3154 fps=0.0 q=-1.0 Lsize=   15708kB time=00:01:53.61 bitrate=1132.6kbits/s speed= 153x
# video:14104kB audio:1505kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.627519%
