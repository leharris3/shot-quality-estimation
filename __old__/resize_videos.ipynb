# %%
import os
import ffmpeg
import shutil


def resize_video(input_path, output_path):
    """Resize the video to a height of 224 pixels while maintaining the aspect ratio."""
    # Stream to get video metadata
    probe = ffmpeg.probe(input_path)
    video_streams = [
        stream for stream in probe["streams"] if stream["codec_type"] == "video"
    ]
    original_width = int(video_streams[0]["width"])
    original_height = int(video_streams[0]["height"])
    new_height = 224
    new_width = 256

    # Command to resize video
    ffmpeg.input(input_path).output(
        output_path, vf=f"scale={new_width}:{new_height}"
    ).run()


def process_directory(directory, output_directory):
    """Process all MP4 files in the directory and subdirectories."""
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".mp4"):
                input_path = os.path.join(root, file)
                relative_path = os.path.relpath(root, directory)
                output_path_root = os.path.join(output_directory, relative_path)
                os.makedirs(output_path_root, exist_ok=True)
                output_path = os.path.join(output_path_root, file)
                resize_video(input_path, output_path)


def main():
    directory = "/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480"
    output_directory = "/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224"
    os.makedirs(output_directory, exist_ok=True)

    process_directory(directory, output_directory)
    print("All videos have been resized and saved in:", output_directory)


if __name__ == "__main__":
    main()
# Out:
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17584_800202_2-_497.78.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 1095 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1093 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x556cb41675c0] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x556cb41675c0] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17584_800202_2-_497.78.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  121 fps=0.0 q=15.8 Lsize=     208kB time=00:00:04.00 bitrate= 426.6kbits/s speed=4.07x
# video:207kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.662170%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17587_800202_2-_584.247.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 1068 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1065 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x564cc1ea9a40] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x564cc1ea9a40] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17587_800202_2-_584.247.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  121 fps=119 q=12.2 Lsize=     213kB time=00:00:04.00 bitrate= 436.8kbits/s speed=3.92x
# video:212kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.646478%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17590_800202_2-_533.009.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 1226 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1223 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x561bede32680] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x561bede32680] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17590_800202_2-_533.009.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  121 fps=104 q=15.0 Lsize=     209kB time=00:00:04.00 bitrate= 427.1kbits/s speed=3.44x
# video:207kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.661349%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17583_800202_2-_335.323.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 1367 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1364 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x5562b74bc0c0] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x5562b74bc0c0] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17583_800202_2-_335.323.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=0.0 q=25.8 Lsize=     217kB time=00:00:03.96 bitrate= 447.9kbits/s speed=4.92x
# video:216kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.632134%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17599_800202_2-_116.113.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 943 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 940 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55e7cdabc900] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x55e7cdabc900] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17599_800202_2-_116.113.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  121 fps= 98 q=10.0 Lsize=     207kB time=00:00:04.00 bitrate= 424.6kbits/s speed=3.24x
# video:206kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.665247%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17589_800202_2-_940.929.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 1234 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1232 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x558f070c10c0] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x558f070c10c0] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17589_800202_2-_940.929.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=113 q=24.1 Lsize=     193kB time=00:00:03.96 bitrate= 398.0kbits/s speed=3.74x
# video:191kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.711833%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17594_800202_2-_674.732.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 906 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 903 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55fb25e650c0] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x55fb25e650c0] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17594_800202_2-_674.732.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=0.0 q=14.1 Lsize=     199kB time=00:00:03.96 bitrate= 411.7kbits/s speed=4.63x
# video:198kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.688022%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17585_800202_2-_595.653.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 1317 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1314 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x56133f3c4640] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x56133f3c4640] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17585_800202_2-_595.653.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=0.0 q=23.9 Lsize=     197kB time=00:00:03.96 bitrate= 407.0kbits/s speed=5.46x
# video:196kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.696104%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17584_800302_3-_866.924.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 1259 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1256 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x562f2eaeb080] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x562f2eaeb080] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17584_800302_3-_866.924.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=0.0 q=18.0 Lsize=     220kB time=00:00:03.96 bitrate= 454.5kbits/s speed=8.56x
# video:219kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.622890%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17588_800202_2-_1006.241.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 900 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 897 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x558b934ece80] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0x558b934ece80] too many threads/slices (15), reducing to 14
# Output #0, mp4, to '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_224x224/missed/17588_800202_2-_1006.241.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 256x224 [SAR 255:164 DAR 510:287], q=2-31, 200 kb/s, SAR 5971:3840 DAR 853:480, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  121 fps=0.0 q=13.2 Lsize=     196kB time=00:00:04.00 bitrate= 401.7kbits/s speed=5.03x
# video:195kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.703385%
# ffmpeg version 4.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda/conda-bld/ffmpeg_1597178665428/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeh --cc=/opt/conda/conda-bld/ffmpeg_1597178665428/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/playpen-storage/levlevi/contextualized-shot-quality-analysis/data/experiments/test-sets/result-hidden/nba_.5k_imbalanced_4s_856x480/missed/17585_800302_3-_835.136.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 1201 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 853x480 [SAR 1:1 DAR 853:480], 1198 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# [mpeg4 @ 0x55e8046c4780] Invalid pixel aspect ratio 5971/3840, limit is 255/255 reducing
# [mpeg4 @ 0